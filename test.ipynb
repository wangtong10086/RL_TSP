# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import tsplib95

class TSPEnv_new:
    def __init__(self, problem_file):
        self.problem_file = problem_file
        self.n_cities, self.nodes, self.node_coords, self.problem = self._load_problem()
        self.city_index_to_name = {i: name for i, name in enumerate(self.nodes)}
        self.action_space = self.n_cities
        self.observation_space = self.n_cities
        self.visited_cities = []
        self._generate_distances()

    def _load_problem(self):
        problem = tsplib95.load(self.problem_file)
        n_nodes = problem.dimension
        nodes = list(problem.get_nodes())
        node_coords = {node: problem.node_coords[node] for node in nodes}
        return n_nodes, nodes, node_coords, problem

    def _generate_distances(self):
        coords = np.array(list(self.node_coords.values()))
        self.distances = cdist(coords, coords)

    def reset(self):
        self.visited_cities = []
        first_city = np.random.randint(self.n_cities)
        self.visited_cities.append(first_city)
        return first_city

    def step(self, action):
        current_city_index = self.visited_cities[-1]
        new_city_index = action
        # print(new_city_index)
        reward = -self.distances[current_city_index, new_city_index]

        self.visited_cities.append(new_city_index)
        done = len(self.visited_cities) == self.n_cities

        return new_city_index, reward, done

    def render(self):
        coords = np.array(list(self.node_coords.values()))
        plt.figure(figsize=(7, 7))
        plt.scatter(coords[:, 0], coords[:, 1], c="red", s=50)
        if len(self.visited_cities) > 1:
            plt.plot(coords[self.visited_cities, 0], coords[self.visited_cities, 1], c="blue", linewidth=1, linestyle="--")
        plt.xticks([])
        plt.yticks([])
        plt.show()

    def close(self):
        plt.close()

# %%
def visualize_tsp_solution(nodes, visited_order, title="TSP Solution", save_path="results", save_img=True):
    fig, ax = plt.subplots()
    plt.scatter(nodes[:, 0], nodes[:, 1], c="blue", zorder=1)
    
    for i, node in enumerate(nodes):
        ax.annotate(i + 1, (node[0], node[1]), fontsize=8, zorder=2)
        
    visited_nodes = nodes[visited_order]
    
    for i in range(len(visited_nodes) - 1):
        plt.plot([visited_nodes[i][0], visited_nodes[i+1][0]], [visited_nodes[i][1], visited_nodes[i+1][1]], c="red", zorder=0)
    plt.plot([visited_nodes[-1][0], visited_nodes[0][0]], [visited_nodes[-1][1], visited_nodes[0][1]], c="red", zorder=0)
    
    plt.title(title)
    if save_img:
        plt.savefig(os.path.join(save_path, "tsp_solution.png"))
    plt.show()

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import random

class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=64):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class ComplexQNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ComplexQNetwork, self).__init__()
        
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 128)
        self.fc5 = nn.Linear(128, output_dim)
        
        self.dropout = nn.Dropout(p=0.1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = F.relu(self.fc4(x))
        x = self.dropout(x)
        x = self.fc5(x)
        
        return x

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DQNAgent:
    def __init__(self, input_dim,env, output_dim, q_network_class, hidden_dim=64, buffer_size=10000,
                 batch_size=128, gamma=0.99, learning_rate=1e-4,
                 epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995):
        self.env = env
        self.q_network = q_network_class(input_dim, output_dim)
        self.target_network = q_network_class(input_dim, output_dim)
        self.target_network.load_state_dict(self.q_network.state_dict())
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=learning_rate)
        self.buffer = ReplayBuffer(buffer_size)
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.visited_nodes = set()

    def reset_visited_nodes(self):
        self.visited_nodes = set()

    def predict(self, current_city, deterministic=False):
        # Get the coordinates of the current city
        current_city_coords = self.env.node_coords[current_city]
        
        # Compute the relative coordinates of all cities to the current city
        relative_coords = {city: (coords[0] - current_city_coords[0], coords[1] - current_city_coords[1]) 
                        for city, coords in self.env.node_coords.items()}
        
        # Flatten the relative coordinates and convert it to a tensor
        observation = np.array(list(relative_coords.values())).flatten()
        observation = torch.tensor(observation, dtype=torch.float32).unsqueeze(0)

        q_values = self.q_network(observation).detach().numpy().flatten()

        # Mask already visited nodes with -np.inf
        for visited_node_index in self.visited_nodes:
            q_values[visited_node_index] = -np.inf

        # Choose the action
        if deterministic or np.random.rand() > self.epsilon:
            action = np.argmax(q_values)
        else:
            action = np.random.choice([x for x in range(len(q_values)) if x not in self.visited_nodes])

        return action


    def update(self, state, action, reward, next_state, done):
        # Convert the states into the same form as in the 'predict' method
        current_city_coords = self.env.node_coords[state]
        relative_coords = {city: (coords[0] - current_city_coords[0], coords[1] - current_city_coords[1]) 
                        for city, coords in self.env.node_coords.items()}
        state = np.array(list(relative_coords.values())).flatten()

        next_city_name = self.env.city_index_to_name[next_state]
        next_city_coords = self.env.node_coords[self.env.city_index_to_name[next_state]]
        next_relative_coords = {city: (coords[0] - next_city_coords[0], coords[1] - next_city_coords[1]) 
                                for city, coords in self.env.node_coords.items()}
        next_state = np.array(list(next_relative_coords.values())).flatten()

        self.buffer.add((state, action, reward, next_state, done))

        if len(self.buffer) >= self.batch_size:
            experiences = self.buffer.sample(self.batch_size)

            # Extract the values from the experiences
            states, actions, rewards, next_states, dones = zip(*experiences)

            states = torch.tensor(states, dtype=torch.float32)
            actions = torch.tensor(actions, dtype=torch.long).unsqueeze(-1)
            rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
            next_states = torch.tensor(next_states, dtype=torch.float32)
            dones = torch.tensor(dones, dtype=torch.bool).unsqueeze(-1)

            q_values = self.q_network(states).gather(1, actions)
            next_q_values = self.target_network(next_states).max(1, keepdim=True)[0].detach()
            target_q_values = rewards + (self.gamma * next_q_values * ~dones)

            loss = nn.MSELoss()(q_values, target_q_values)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            # Update epsilon
            self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)


    def update_target_network(self):
        self.target_network.load_state_dict(self.q_network.state_dict())

    def save(self, filepath):
        torch.save(self.q_network.state_dict(), filepath)

    def load(self, filepath):
        self.q_network.load_state_dict(torch.load(filepath))

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
import matplotlib.pyplot as plt


def train_dqn(env, agent, n_episodes=100, update_target_every=10, save_path="results",save_img=True):
    os.makedirs(save_path, exist_ok=True)

    rewards = []  # 存储每个episode的reward
    for episode in range(n_episodes):
        agent.reset_visited_nodes()
        state = env.reset()
        done = False
        episode_reward = 0
        actions=[]
        while not done:
            state+=1
            action = agent.predict(state)
            
            next_state, reward, done = env.step(action)
            agent.update(state, action, reward, next_state, done)
            agent.visited_nodes.add(action)
            state = next_state
            episode_reward += reward

        if episode % update_target_every == 0:
            agent.update_target_network()

        rewards.append(episode_reward)  # 将当前episode的总reward存储到列表中
        print(f"Episode {episode}: reward = {episode_reward}, length = {len(agent.visited_nodes)}")

    # 绘制reward随episode变化的折线图
    plt.plot(range(n_episodes), rewards)
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    if save_img:
        plt.savefig(os.path.join(save_path, "reward_plot.png"))
    plt.show()

    # 保存训练好的模型
    agent.save(os.path.join(save_path, "dqn_tsp_model.pt"))



# Create TSP environment
tsp_env = TSPEnv_new("tsp/a280.tsp")

# Create DQN agent
agent = DQNAgent(input_dim=2 * tsp_env.n_cities, env=tsp_env,output_dim=tsp_env.n_cities, q_network_class=ComplexQNetwork)
train_dqn(tsp_env, agent, n_episodes=100, save_path="results", save_img=True)

# %%
def inference_dqn(env, agent, save_path="results", save_img=True):
    # 加载模型进行推理
    loaded_agent =agent
    loaded_agent.load(os.path.join(save_path, "dqn_tsp_model.pt"))
    
    state = env.reset()
    done = False
    visited_order = []
    print(state)

    agent.reset_visited_nodes()
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state+=1
        action = agent.predict(state)
        
        next_state, reward, done = env.step(action)
        agent.update(state, action, reward, next_state, done)
        agent.visited_nodes.add(action)
        visited_order.append(action)
        state = next_state
        episode_reward += reward

    # 可视化解决方案
    nodes = np.array([env.problem.node_coords[node] for node in env.nodes])
    visualize_tsp_solution(nodes, visited_order, save_path=save_path, save_img=save_img)

# %%
test_env = TSPEnv_new("tsp/a280.tsp")


loaded_agent=DQNAgent(input_dim=2 * test_env.n_cities,env=test_env,output_dim=test_env.n_cities, q_network_class=ComplexQNetwork)
inference_dqn(test_env, agent, save_path="results", save_img=True)
# Out:
# 258

# %% [markdown]
# # 2

# %%
# Create TSP environment
file='ali535.tsp'
tsp_env = TSPEnv_new("tsp"+file)

# Create DQN agent
agent = DQNAgent(input_dim=2 * tsp_env.n_cities, env=tsp_env,output_dim=tsp_env.n_cities, q_network_class=ComplexQNetwork)
train_dqn(tsp_env, agent, n_episodes=100, save_path="results/"+file, save_img=True)
inference_dqn(tsp_env, agent, save_path="results/"+file, save_img=True)
# Out:
# Episode 0: reward = -40154.67385377206, length = 534
# Episode 1: reward = -35033.63934188992, length = 534
# Episode 2: reward = -28662.939625560837, length = 534
# Episode 3: reward = -23617.609872056986, length = 534
# Episode 4: reward = -20590.957197479867, length = 534
# Episode 5: reward = -19185.980061875984, length = 534
# Episode 6: reward = -17760.242064903545, length = 534
# Episode 7: reward = -15489.039814859869, length = 534
# Episode 8: reward = -14103.547084875616, length = 534
# Episode 9: reward = -14065.95539182072, length = 534
# Episode 10: reward = -11957.00710258789, length = 534
# Episode 11: reward = -11556.133651178618, length = 534
# Episode 12: reward = -11282.39200329407, length = 534
# Episode 13: reward = -10569.176016839627, length = 534
# Episode 14: reward = -9393.19687324114, length = 534
# Episode 15: reward = -8859.979248142035, length = 534
# Episode 16: reward = -8923.753168683546, length = 534
# Episode 17: reward = -8510.214992753945, length = 534
# Episode 18: reward = -8204.09821636381, length = 534
# Episode 19: reward = -8630.745279465416, length = 534
# Episode 20: reward = -7680.763024399194, length = 534
# Episode 21: reward = -7359.899262218288, length = 534
# Episode 22: reward = -7402.27300446997, length = 534
# Episode 23: reward = -7094.39391956855, length = 534
# Episode 24: reward = -6363.911686347401, length = 534
# Episode 25: reward = -6552.844096938087, length = 534
# Episode 26: reward = -6253.767758589291, length = 534
# Episode 27: reward = -5817.012940469515, length = 534
# Episode 28: reward = -5742.279000845315, length = 534
# Episode 29: reward = -5793.220612028838, length = 534
# Episode 30: reward = -5825.930939513415, length = 534
# Episode 31: reward = -5844.335454453348, length = 534
# Episode 32: reward = -5296.201851222888, length = 534
# Episode 33: reward = -5592.789855800484, length = 534
# Episode 34: reward = -5302.101600050455, length = 534
# Episode 35: reward = -5545.470388920327, length = 534
# Episode 36: reward = -4998.122348906941, length = 534
# Episode 37: reward = -5526.132222994177, length = 534
# Episode 38: reward = -5563.184817860057, length = 534
# Episode 39: reward = -4871.975408276827, length = 534
# Episode 40: reward = -4855.849398255778, length = 534
# Episode 41: reward = -5336.220478777924, length = 534
# Episode 42: reward = -5282.978884396945, length = 534
# Episode 43: reward = -5261.134237415572, length = 534
# Episode 44: reward = -4728.276092077698, length = 534
# Episode 45: reward = -4938.24422936192, length = 534
# Episode 46: reward = -4887.3299523169935, length = 534
# Episode 47: reward = -4983.386878462508, length = 534
# Episode 48: reward = -4859.931499005483, length = 534
# Episode 49: reward = -4348.757145640515, length = 534
# Episode 50: reward = -4771.748406819508, length = 534
# Episode 51: reward = -5098.579588371479, length = 534
# Episode 52: reward = -5218.850391085889, length = 534
# Episode 53: reward = -4634.426611678061, length = 534
# Episode 54: reward = -4934.717915889786, length = 534
# Episode 55: reward = -4747.065324766714, length = 534
# Episode 56: reward = -4550.629423076305, length = 534
# Episode 57: reward = -5140.190393655027, length = 534
# Episode 58: reward = -4522.307387346173, length = 534
# Episode 59: reward = -4705.977892842021, length = 534
# Episode 60: reward = -4789.0524556568025, length = 534
# Episode 61: reward = -4493.71379766852, length = 534
# Episode 62: reward = -4341.594201386398, length = 534
# Episode 63: reward = -4376.061195424125, length = 534
# Episode 64: reward = -4466.715417655521, length = 534
# Episode 65: reward = -4357.702455053273, length = 534
# Episode 66: reward = -4496.888931684573, length = 534
# Episode 67: reward = -4627.881722569821, length = 534
# Episode 68: reward = -4506.543460382156, length = 534
# Episode 69: reward = -4673.937351078857, length = 534
# Episode 70: reward = -4698.211809670713, length = 534
# Episode 71: reward = -4660.8271148775275, length = 534
# Episode 72: reward = -4379.513509741958, length = 534
# Episode 73: reward = -4468.534042327362, length = 534
# Episode 74: reward = -4836.111963110808, length = 534
# Episode 75: reward = -4323.551173867815, length = 534
# Episode 76: reward = -4440.779078119945, length = 534
# Episode 77: reward = -4226.552251477898, length = 534
# Episode 78: reward = -4688.301246895495, length = 534
# Episode 79: reward = -4553.260107435862, length = 534
# Episode 80: reward = -4467.664807817871, length = 534
# Episode 81: reward = -4206.242528344363, length = 534
# Episode 82: reward = -4542.5406746621975, length = 534
# Episode 83: reward = -4144.326758717461, length = 534
# Episode 84: reward = -4119.08185146199, length = 534
# Episode 85: reward = -4628.90932738864, length = 534
# Episode 86: reward = -4342.528914869002, length = 534
# Episode 87: reward = -4464.871767445231, length = 534
# Episode 88: reward = -5278.32356204604, length = 534
# Episode 89: reward = -4337.580260402881, length = 534
# Episode 90: reward = -4477.714878594411, length = 534
# Episode 91: reward = -4608.856843357429, length = 534
# Episode 92: reward = -4443.399915377903, length = 534
# Episode 93: reward = -4477.2172308603285, length = 534
# Episode 94: reward = -4728.313761204981, length = 534
# Episode 95: reward = -4638.348915352372, length = 534
# Episode 96: reward = -4239.036352230984, length = 534
# Episode 97: reward = -4613.6247975940205, length = 534
# Episode 98: reward = -4162.6949484485385, length = 534
# Episode 99: reward = -4371.702052301467, length = 534
# 348

# %% [markdown]
# # 3

# %%
# Create TSP environment
file='att48.tsp'
tsp_env = TSPEnv_new("tsp/"+file)

# Create DQN agent
agent = DQNAgent(input_dim=2 * tsp_env.n_cities, env=tsp_env,output_dim=tsp_env.n_cities, q_network_class=ComplexQNetwork)
train_dqn(tsp_env, agent, n_episodes=100, save_path="results/"+file, save_img=True)
inference_dqn(tsp_env, agent, save_path="results/"+file, save_img=True)
# Out:
# Episode 0: reward = -168040.8104886791, length = 47
# Episode 1: reward = -151630.3896051074, length = 47
# Episode 2: reward = -165793.4683251699, length = 47
# Episode 3: reward = -150952.58873036507, length = 47
# Episode 4: reward = -136101.16141546174, length = 47
# Episode 5: reward = -135714.2007097228, length = 47
# Episode 6: reward = -108984.10500390055, length = 47
# Episode 7: reward = -103820.39914650434, length = 47
# Episode 8: reward = -113549.12573303554, length = 47
# Episode 9: reward = -88776.55675133878, length = 47
# Episode 10: reward = -86624.06491131861, length = 47
# Episode 11: reward = -96159.30732078568, length = 47
# Episode 12: reward = -79841.72669911676, length = 47
# Episode 13: reward = -78049.50604621698, length = 47
# Episode 14: reward = -71890.45008588767, length = 47
# Episode 15: reward = -58928.84970647813, length = 47
# Episode 16: reward = -69963.41887798937, length = 47
# Episode 17: reward = -62517.143030414074, length = 47
# Episode 18: reward = -51515.9784031552, length = 47
# Episode 19: reward = -61788.622781595994, length = 47
# Episode 20: reward = -57793.056051517386, length = 47
# Episode 21: reward = -54925.35310907803, length = 47
# Episode 22: reward = -51262.281576035406, length = 47
# Episode 23: reward = -47882.70544310221, length = 47
# Episode 24: reward = -58094.251457569284, length = 47
# Episode 25: reward = -55380.952133353436, length = 47
# Episode 26: reward = -55858.48580555833, length = 47
# Episode 27: reward = -49663.632366085105, length = 47
# Episode 28: reward = -52265.107433385674, length = 47
# Episode 29: reward = -49010.485906192705, length = 47
# Episode 30: reward = -46908.77571528756, length = 47
# Episode 31: reward = -40649.71877166447, length = 47
# Episode 32: reward = -50606.25782752772, length = 47
# Episode 33: reward = -44865.450875980445, length = 47
# Episode 34: reward = -45846.92944026218, length = 47
# Episode 35: reward = -52282.06180380969, length = 47
# Episode 36: reward = -46047.34571780596, length = 47
# Episode 37: reward = -46695.221600522294, length = 47
# Episode 38: reward = -51378.48220589179, length = 47
# Episode 39: reward = -46790.41560981868, length = 47
# Episode 40: reward = -47429.85266863515, length = 47
# Episode 41: reward = -46334.867647980915, length = 47
# Episode 42: reward = -43410.36224262464, length = 47
# Episode 43: reward = -47324.79312044357, length = 47
# Episode 44: reward = -45011.25254597865, length = 47
# Episode 45: reward = -40289.03911768884, length = 47
# Episode 46: reward = -47731.64694697177, length = 47
# Episode 47: reward = -49120.481545250004, length = 47
# Episode 48: reward = -52822.36454397647, length = 47
# Episode 49: reward = -37396.42767473241, length = 47
# Episode 50: reward = -42565.16664914671, length = 47
# Episode 51: reward = -39580.71052422403, length = 47
# Episode 52: reward = -43222.62935422173, length = 47
# Episode 53: reward = -53830.40819581956, length = 47
# Episode 54: reward = -44116.44628355439, length = 47
# Episode 55: reward = -47730.01563426234, length = 47
# Episode 56: reward = -42033.79491126588, length = 47
# Episode 57: reward = -57361.50644455409, length = 47
# Episode 58: reward = -42472.709463839994, length = 47
# Episode 59: reward = -42862.237083238695, length = 47
# Episode 60: reward = -49397.56168362654, length = 47
# Episode 61: reward = -49687.9185417541, length = 47
# Episode 62: reward = -42939.28552845892, length = 47
# Episode 63: reward = -44470.8033557227, length = 47
# Episode 64: reward = -44762.05226524052, length = 47
# Episode 65: reward = -41807.51321904868, length = 47
# Episode 66: reward = -43573.41601596516, length = 47
# Episode 67: reward = -43065.39019300174, length = 47
# Episode 68: reward = -44756.85538980711, length = 47
# Episode 69: reward = -38477.21161567776, length = 47
# Episode 70: reward = -42473.07712205637, length = 47
# Episode 71: reward = -44229.953400644554, length = 47
# Episode 72: reward = -51556.63369409286, length = 47
# Episode 73: reward = -43105.03849243015, length = 47
# Episode 74: reward = -39176.15986828521, length = 47
# Episode 75: reward = -42368.647450658464, length = 47
# Episode 76: reward = -39633.82680600738, length = 47
# Episode 77: reward = -41846.43945821003, length = 47
# Episode 78: reward = -40656.06504154539, length = 47
# Episode 79: reward = -37634.166863261766, length = 47
# Episode 80: reward = -44049.921010241545, length = 47
# Episode 81: reward = -38886.26536990482, length = 47
# Episode 82: reward = -35671.62690988224, length = 47
# Episode 83: reward = -41233.6034424542, length = 47
# Episode 84: reward = -37886.417070540265, length = 47
# Episode 85: reward = -43744.58776062721, length = 47
# Episode 86: reward = -42644.737892036435, length = 47
# Episode 87: reward = -40461.25162947114, length = 47
# Episode 88: reward = -40941.15013992395, length = 47
# Episode 89: reward = -37975.350909107554, length = 47
# Episode 90: reward = -47834.12725285532, length = 47
# Episode 91: reward = -39442.32132267404, length = 47
# Episode 92: reward = -43168.566866007146, length = 47
# Episode 93: reward = -49454.74009988235, length = 47
# Episode 94: reward = -38883.67793664086, length = 47
# Episode 95: reward = -39364.35529302216, length = 47
# Episode 96: reward = -42696.912590889195, length = 47
# Episode 97: reward = -40570.938141328064, length = 47
# Episode 98: reward = -39801.07639236015, length = 47
# Episode 99: reward = -59100.87273634518, length = 47
# 22

# %% [markdown]
# # 4

# %%
# Create TSP environment
file='eil101.tsp'
tsp_env = TSPEnv_new("tsp/"+file)

# Create DQN agent
agent = DQNAgent(input_dim=2 * tsp_env.n_cities, env=tsp_env,output_dim=tsp_env.n_cities, q_network_class=ComplexQNetwork)
train_dqn(tsp_env, agent, n_episodes=100, save_path="results/"+file, save_img=True)
inference_dqn(tsp_env, agent, save_path="results/"+file, save_img=True)
# Out:
# Episode 0: reward = -3371.912661121877, length = 100
# Episode 1: reward = -3283.5487951137297, length = 100
# Episode 2: reward = -3462.890294616029, length = 100
# Episode 3: reward = -2931.7772288723713, length = 100
# Episode 4: reward = -2457.9660960001593, length = 100
# Episode 5: reward = -2105.929006156858, length = 100
# Episode 6: reward = -1726.8072751965167, length = 100
# Episode 7: reward = -1585.6123942647534, length = 100
# Episode 8: reward = -1480.0963098225984, length = 100
# Episode 9: reward = -1476.325901971372, length = 100
# Episode 10: reward = -1334.953564374978, length = 100
# Episode 11: reward = -1343.0549127949919, length = 100
# Episode 12: reward = -1300.2885248905673, length = 100
# Episode 13: reward = -1399.018252118067, length = 100
# Episode 14: reward = -1389.0683523108964, length = 100
# Episode 15: reward = -1233.9216248133916, length = 100
# Episode 16: reward = -1258.5821174846806, length = 100
# Episode 17: reward = -1291.7665189671297, length = 100
# Episode 18: reward = -1248.7273705071157, length = 100
# Episode 19: reward = -1177.4680074645116, length = 100
# Episode 20: reward = -1196.9156049759122, length = 100
# Episode 21: reward = -1236.4520747122292, length = 100
# Episode 22: reward = -1140.157703833872, length = 100
# Episode 23: reward = -1104.6448802410473, length = 100
# Episode 24: reward = -1130.2989411012193, length = 100
# Episode 25: reward = -1091.4857892027558, length = 100
# Episode 26: reward = -1066.0448185654554, length = 100
# Episode 27: reward = -1152.5697491616831, length = 100
# Episode 28: reward = -998.5707583258408, length = 100
# Episode 29: reward = -1033.7556659077302, length = 100
# Episode 30: reward = -1094.1870203179449, length = 100
# Episode 31: reward = -1101.0186716803428, length = 100
# Episode 32: reward = -1055.4041845836673, length = 100
# Episode 33: reward = -1102.5511989452227, length = 100
# Episode 34: reward = -985.4801592058785, length = 100
# Episode 35: reward = -1056.8899418438966, length = 100
# Episode 36: reward = -944.210163380193, length = 100
# Episode 37: reward = -1055.3240029631409, length = 100
# Episode 38: reward = -1045.769969720798, length = 100
# Episode 39: reward = -926.7909920407405, length = 100
# Episode 40: reward = -1073.8531831981459, length = 100
# Episode 41: reward = -1049.7379298676808, length = 100
# Episode 42: reward = -1007.1498033858393, length = 100
# Episode 43: reward = -1012.3828261522216, length = 100
# Episode 44: reward = -936.404000385929, length = 100
# Episode 45: reward = -948.8490350025669, length = 100
# Episode 46: reward = -950.4519406773321, length = 100
# Episode 47: reward = -1025.8172600947385, length = 100
# Episode 48: reward = -994.4403737910384, length = 100
# Episode 49: reward = -1002.7210514544109, length = 100
# Episode 50: reward = -980.0465955148812, length = 100
# Episode 51: reward = -1002.3905410974696, length = 100
# Episode 52: reward = -991.0088040139474, length = 100
# Episode 53: reward = -1073.0621026122578, length = 100
# Episode 54: reward = -909.2716519548193, length = 100
# Episode 55: reward = -953.5129760630691, length = 100
# Episode 56: reward = -993.6922524544868, length = 100
# Episode 57: reward = -1000.8924456675294, length = 100
# Episode 58: reward = -992.3282073347535, length = 100
# Episode 59: reward = -1118.9303734399668, length = 100
# Episode 60: reward = -1043.0306384015619, length = 100
# Episode 61: reward = -961.0580690525145, length = 100
# Episode 62: reward = -994.3344397135729, length = 100
# Episode 63: reward = -1041.143930807282, length = 100
# Episode 64: reward = -920.9641291047367, length = 100
# Episode 65: reward = -1034.6184217799985, length = 100
# Episode 66: reward = -918.2426266435535, length = 100
# Episode 67: reward = -976.0514706510071, length = 100
# Episode 68: reward = -908.5553840880176, length = 100
# Episode 69: reward = -1036.7885960380577, length = 100
# Episode 70: reward = -995.9312155977716, length = 100
# Episode 71: reward = -924.0040902744099, length = 100
# Episode 72: reward = -901.7175317287732, length = 100
# Episode 73: reward = -894.8148375978212, length = 100
# Episode 74: reward = -1132.34098563642, length = 100
# Episode 75: reward = -943.7761672545156, length = 100
# Episode 76: reward = -994.94590791665, length = 100
# Episode 77: reward = -906.7377797988934, length = 100
# Episode 78: reward = -883.5426770972033, length = 100
# Episode 79: reward = -929.1649602088811, length = 100
# Episode 80: reward = -899.4291081849113, length = 100
# Episode 81: reward = -968.9928643523263, length = 100
# Episode 82: reward = -895.8781049377335, length = 100
# Episode 83: reward = -925.649784807013, length = 100
# Episode 84: reward = -936.4445010985561, length = 100
# Episode 85: reward = -919.1445503748108, length = 100
# Episode 86: reward = -970.8966027870122, length = 100
# Episode 87: reward = -921.3218734319119, length = 100
# Episode 88: reward = -989.4675812036853, length = 100
# Episode 89: reward = -939.1038321087495, length = 100
# Episode 90: reward = -923.6472393720228, length = 100
# Episode 91: reward = -858.0035202594656, length = 100
# Episode 92: reward = -886.3324055378217, length = 100
# Episode 93: reward = -981.2971435681804, length = 100
# Episode 94: reward = -954.5354440776459, length = 100
# Episode 95: reward = -888.2702325880446, length = 100
# Episode 96: reward = -950.0160731376811, length = 100
# Episode 97: reward = -879.2568865436745, length = 100
# Episode 98: reward = -925.8832152223199, length = 100
# Episode 99: reward = -915.8693506021698, length = 100
# 44
